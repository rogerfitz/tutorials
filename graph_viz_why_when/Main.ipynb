# %%
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline

# %%
table="""
<table class="sortable wikitable plainrowheaders jquery-tablesorter" style="font-size:100%; width: 98%">
<thead><tr>
<th scope="col" style="width:4%" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending"><abbr title="Number"><span style="visibility:hidden;color:transparent;">0</span>#<span style="visibility:hidden;color:transparent;">0</span></abbr></th>
<th scope="col" style="width:4%" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending"><abbr title="Position">Pos.</abbr></th>
<th scope="col" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Player</th>
<th scope="col" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Date of birth (age)</th>
<th scope="col" style="width:7%" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Caps</th>
<th scope="col" style="width:7%" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Goals</th>
<th scope="col" class="headerSort" tabindex="0" role="columnheader button" title="Sort ascending">Club</th>
</tr></thead><tbody>
<tr>
<td style="text-align:center; border:0">1</td>
<td style="text-align:center; border:0"><span style="display:none">1</span><a href="/wiki/Goalkeeper_(association_football)" title="Goalkeeper (association football)">GK</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Gianluigi_Buffon" title="Gianluigi Buffon">Gianluigi Buffon</a> <small><i>(<a href="/wiki/Captain_(association_football)" title="Captain (association football)">captain</a>)</i></small></th>
<td style="border:0"><span style="display:none">(<span class="bday">1978-01-28</span>)</span> 28 January 1978 <span class="noprint ForceAgeToShow">(age&nbsp;39)</span></td>
<td style="text-align:center; border:0">169</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Juventus_F.C." title="Juventus F.C.">Juventus</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">12</td>
<td style="text-align:center; border:0"><span style="display:none">1</span><a href="/wiki/Goalkeeper_(association_football)" title="Goalkeeper (association football)">GK</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Gianluigi_Donnarumma" title="Gianluigi Donnarumma">Gianluigi Donnarumma</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1999-02-25</span>)</span> 25 February 1999 <span class="noprint ForceAgeToShow">(age&nbsp;18)</span></td>
<td style="text-align:center; border:0">4</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/A.C._Milan" title="A.C. Milan">Milan</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">14</td>
<td style="text-align:center; border:0"><span style="display:none">1</span><a href="/wiki/Goalkeeper_(association_football)" title="Goalkeeper (association football)">GK</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Simone_Scuffet" title="Simone Scuffet">Simone Scuffet</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1996-05-31</span>)</span> 31 May 1996 <span class="noprint ForceAgeToShow">(age&nbsp;21)</span></td>
<td style="text-align:center; border:0">0</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Udinese_Calcio" title="Udinese Calcio">Udinese</a></td>
</tr>
<tr class="sortbottom">
<td colspan="7" style="border:0;opacity:.75">
<hr></td>
</tr>
<tr>
<td style="text-align:center; border:0">2</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Andrea_Conti_(footballer,_born_1994)" title="Andrea Conti (footballer, born 1994)">Andrea Conti</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1994-03-02</span>)</span> 2 March 1994 <span class="noprint ForceAgeToShow">(age&nbsp;23)</span></td>
<td style="text-align:center; border:0">0</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Atalanta_B.C." title="Atalanta B.C.">Atalanta</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">3</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Giorgio_Chiellini" title="Giorgio Chiellini">Giorgio Chiellini</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1984-08-14</span>)</span> 14 August 1984 <span class="noprint ForceAgeToShow">(age&nbsp;32)</span></td>
<td style="text-align:center; border:0">92</td>
<td style="text-align:center; border:0">7</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Juventus_F.C." title="Juventus F.C.">Juventus</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">4</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Matteo_Darmian" title="Matteo Darmian">Matteo Darmian</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1989-12-02</span>)</span> 2 December 1989 <span class="noprint ForceAgeToShow">(age&nbsp;27)</span></td>
<td style="text-align:center; border:0">30</td>
<td style="text-align:center; border:0">1</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/England" title="England"><img alt="England" src="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/23px-Flag_of_England.svg.png" width="23" height="14" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/35px-Flag_of_England.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/46px-Flag_of_England.svg.png 2x" data-file-width="800" data-file-height="480"></a></span> <a href="/wiki/Manchester_United_F.C." title="Manchester United F.C.">Manchester United</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">7</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Leonardo_Spinazzola" title="Leonardo Spinazzola">Leonardo Spinazzola</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1993-03-25</span>)</span> 25 March 1993 <span class="noprint ForceAgeToShow">(age&nbsp;24)</span></td>
<td style="text-align:center; border:0">3</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Atalanta_B.C." title="Atalanta B.C.">Atalanta</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">13</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Davide_Astori" title="Davide Astori">Davide Astori</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1987-01-07</span>)</span> 7 January 1987 <span class="noprint ForceAgeToShow">(age&nbsp;30)</span></td>
<td style="text-align:center; border:0">13</td>
<td style="text-align:center; border:0">1</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/ACF_Fiorentina" title="ACF Fiorentina">Fiorentina</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">15</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Andrea_Barzagli" title="Andrea Barzagli">Andrea Barzagli</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1981-05-08</span>)</span> 8 May 1981 <span class="noprint ForceAgeToShow">(age&nbsp;36)</span></td>
<td style="text-align:center; border:0">68</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Juventus_F.C." title="Juventus F.C.">Juventus</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">19</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Leonardo_Bonucci" title="Leonardo Bonucci">Leonardo Bonucci</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1987-05-01</span>)</span> 1 May 1987 <span class="noprint ForceAgeToShow">(age&nbsp;30)</span></td>
<td style="text-align:center; border:0">70</td>
<td style="text-align:center; border:0">5</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Juventus_F.C." title="Juventus F.C.">Juventus</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">21</td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Danilo_D%27Ambrosio" title="Danilo D'Ambrosio">Danilo D'Ambrosio</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1988-09-09</span>)</span> 9 September 1988 <span class="noprint ForceAgeToShow">(age&nbsp;28)</span></td>
<td style="text-align:center; border:0">1</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Inter_Milan" title="Inter Milan">Internazionale</a></td>
</tr>
<tr>
<td style="text-align:center; border:0"></td>
<td style="text-align:center; border:0"><span style="display:none">2</span><a href="/wiki/Defender_(association_football)" title="Defender (association football)">DF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Gian_Marco_Ferrari" title="Gian Marco Ferrari">Gian Marco Ferrari</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1992-02-15</span>)</span> 15 February 1992 <span class="noprint ForceAgeToShow">(age&nbsp;25)</span></td>
<td style="text-align:center; border:0">0</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/F.C._Crotone" title="F.C. Crotone">Crotone</a></td>
</tr>
<tr class="sortbottom">
<td colspan="7" style="border:0;opacity:.75">
<hr></td>
</tr>
<tr>
<td style="text-align:center; border:0">5</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Lorenzo_Pellegrini" title="Lorenzo Pellegrini">Lorenzo Pellegrini</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1996-06-19</span>)</span> 19 June 1996 <span class="noprint ForceAgeToShow">(age&nbsp;21)</span></td>
<td style="text-align:center; border:0">1</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/A.S._Roma" title="A.S. Roma">Roma</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">6</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Antonio_Candreva" title="Antonio Candreva">Antonio Candreva</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1987-02-28</span>)</span> 28 February 1987 <span class="noprint ForceAgeToShow">(age&nbsp;30)</span></td>
<td style="text-align:center; border:0">47</td>
<td style="text-align:center; border:0">6</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Inter_Milan" title="Inter Milan">Internazionale</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">8</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Roberto_Gagliardini" title="Roberto Gagliardini">Roberto Gagliardini</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1994-04-07</span>)</span> 7 April 1994 <span class="noprint ForceAgeToShow">(age&nbsp;23)</span></td>
<td style="text-align:center; border:0">1</td>
<td style="text-align:center; border:0">0</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Inter_Milan" title="Inter Milan">Internazionale</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">16</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Daniele_De_Rossi" title="Daniele De Rossi">Daniele De Rossi</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1983-07-24</span>)</span> 24 July 1983 <span class="noprint ForceAgeToShow">(age&nbsp;33)</span></td>
<td style="text-align:center; border:0">114</td>
<td style="text-align:center; border:0">21</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/A.S._Roma" title="A.S. Roma">Roma</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">18</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Riccardo_Montolivo" title="Riccardo Montolivo">Riccardo Montolivo</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1985-01-18</span>)</span> 18 January 1985 <span class="noprint ForceAgeToShow">(age&nbsp;32)</span></td>
<td style="text-align:center; border:0">65</td>
<td style="text-align:center; border:0">2</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/A.C._Milan" title="A.C. Milan">Milan</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">20</td>
<td style="text-align:center; border:0"><span style="display:none">3</span><a href="/wiki/Midfielder" title="Midfielder">MF</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Federico_Bernardeschi" title="Federico Bernardeschi">Federico Bernardeschi</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1994-02-16</span>)</span> 16 February 1994 <span class="noprint ForceAgeToShow">(age&nbsp;23)</span></td>
<td style="text-align:center; border:0">9</td>
<td style="text-align:center; border:0">1</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/ACF_Fiorentina" title="ACF Fiorentina">Fiorentina</a></td>
</tr>
<tr class="sortbottom">
<td colspan="7" style="border:0;opacity:.75">
<hr></td>
</tr>
<tr>
<td style="text-align:center; border:0">9</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Andrea_Belotti" title="Andrea Belotti">Andrea Belotti</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1993-12-20</span>)</span> 20 December 1993 <span class="noprint ForceAgeToShow">(age&nbsp;23)</span></td>
<td style="text-align:center; border:0">9</td>
<td style="text-align:center; border:0">4</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Torino_F.C." title="Torino F.C.">Torino</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">10</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Lorenzo_Insigne" title="Lorenzo Insigne">Lorenzo Insigne</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1991-06-04</span>)</span> 4 June 1991 <span class="noprint ForceAgeToShow">(age&nbsp;26)</span></td>
<td style="text-align:center; border:0">16</td>
<td style="text-align:center; border:0">3</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/S.S.C._Napoli" title="S.S.C. Napoli">Napoli</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">11</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Ciro_Immobile" title="Ciro Immobile">Ciro Immobile</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1990-02-20</span>)</span> 20 February 1990 <span class="noprint ForceAgeToShow">(age&nbsp;27)</span></td>
<td style="text-align:center; border:0">24</td>
<td style="text-align:center; border:0">6</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/S.S._Lazio" title="S.S. Lazio">Lazio</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">17</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/%C3%89der_(Italian_footballer)" title="Éder (Italian footballer)">Éder</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1986-11-15</span>)</span> 15 November 1986 <span class="noprint ForceAgeToShow">(age&nbsp;30)</span></td>
<td style="text-align:center; border:0">23</td>
<td style="text-align:center; border:0">6</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/Inter_Milan" title="Inter Milan">Internazionale</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">22</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Stephan_El_Shaarawy" title="Stephan El Shaarawy">Stephan El Shaarawy</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1992-10-27</span>)</span> 27 October 1992 <span class="noprint ForceAgeToShow">(age&nbsp;24)</span></td>
<td style="text-align:center; border:0">21</td>
<td style="text-align:center; border:0">3</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/Italy" title="Italy"><img alt="Italy" src="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/23px-Flag_of_Italy.svg.png" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/35px-Flag_of_Italy.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/03/Flag_of_Italy.svg/45px-Flag_of_Italy.svg.png 2x" data-file-width="1500" data-file-height="1000"></a></span> <a href="/wiki/A.S._Roma" title="A.S. Roma">Roma</a></td>
</tr>
<tr>
<td style="text-align:center; border:0">23</td>
<td style="text-align:center; border:0"><span style="display:none">4</span><a href="/wiki/Forward_(association_football)" title="Forward (association football)">FW</a></td>
<th scope="row" style="border:0; background-color:inherit"><a href="/wiki/Manolo_Gabbiadini" title="Manolo Gabbiadini">Manolo Gabbiadini</a></th>
<td style="border:0"><span style="display:none">(<span class="bday">1991-11-26</span>)</span> 26 November 1991 <span class="noprint ForceAgeToShow">(age&nbsp;25)</span></td>
<td style="text-align:center; border:0">8</td>
<td style="text-align:center; border:0">2</td>
<td style="border:0"><span class="flagicon"><a href="/wiki/England" title="England"><img alt="England" src="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/23px-Flag_of_England.svg.png" width="23" height="14" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/35px-Flag_of_England.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/be/Flag_of_England.svg/46px-Flag_of_England.svg.png 2x" data-file-width="800" data-file-height="480"></a></span> <a href="/wiki/Southampton_F.C." title="Southampton F.C.">Southampton</a></td>
</tr>
</tbody><tfoot></tfoot></table>
"""

# %%
from bs4 import BeautifulSoup as soup
import pandas as pd

soup=soup(table, "lxml")

# %%
headers=[th.text for th in soup.find("thead").find_all("th")]
headers[0]="#"
values=[]
for tr in soup.find("tbody").find_all("tr"):
    row=[]
    for td in tr.find_all("td"):
        row.append(td.text)
    if tr.find("th"):
        row.insert(2,tr.find("th").text)
    else:
        continue
    values.append(row)
values[0]
# Out:
# [u'1',
#  u'1GK',
#  u'Gianluigi Buffon (captain)',
#  u'(1978-01-28) 28 January 1978 (age\xa039)',
#  u'169',
#  u'0',
#  u' Juventus']

# %%
players=pd.DataFrame(values, columns=headers)
players['Club']=players['Club'].apply(lambda x: x[1:])
players[["#","Pos.","Player","Goals","Club"]]
# Out:
#      # Pos.                      Player Goals               Club
# 0    1  1GK  Gianluigi Buffon (captain)     0           Juventus
# 1   12  1GK        Gianluigi Donnarumma     0              Milan
# 2   14  1GK              Simone Scuffet     0            Udinese
# 3    2  2DF                Andrea Conti     0           Atalanta
# 4    3  2DF           Giorgio Chiellini     7           Juventus
# 5    4  2DF              Matteo Darmian     1  Manchester United
# 6    7  2DF         Leonardo Spinazzola     0           Atalanta
# 7   13  2DF               Davide Astori     1         Fiorentina
# 8   15  2DF             Andrea Barzagli     0           Juventus
# 9   19  2DF            Leonardo Bonucci     5           Juventus
# 10  21  2DF           Danilo D'Ambrosio     0     Internazionale
# 11      2DF          Gian Marco Ferrari     0            Crotone
# 12   5  3MF          Lorenzo Pellegrini     0               Roma
# ...

# %%
import numpy as np
import itertools

# %%
N=len(players)
adj_matrix=np.zeros((N,N))
for club,club_players in players.groupby("Club"):
    for pairs in itertools.combinations(club_players.index,2):
        adj_matrix[pairs[0]][pairs[1]]=1
        adj_matrix[pairs[1]][pairs[0]]=1
G=nx.from_numpy_matrix(adj_matrix)
nx.draw(G,pos=nx.random_layout(G))

# %%
#to Cytoscape
nodes=[]
edges=[]
for club,club_players in players.groupby("Club"):
    for idx, p in club_players.iterrows():
        nodes.append({"data": {"id": p["Player"],"related":"|".join(club_players['Player'].unique())}})
    for pairs in itertools.combinations(club_players.index,2):
        edges.append({"data": {"source": players.ix[pairs[0]]['Player'], "target": players.ix[pairs[1]]['Player']}})
        edges.append({"data": {"source": players.ix[pairs[1]]['Player'], "target": players.ix[pairs[0]]['Player']}})
elements={"nodes": nodes, "edges":edges}

# %%
from json import dumps

# %%
dumps(elements)
# Out:
# '{"nodes": [{"data": {"id": "Andrea Conti", "related": "Andrea Conti|Leonardo Spinazzola"}}, {"data": {"id": "Leonardo Spinazzola", "related": "Andrea Conti|Leonardo Spinazzola"}}, {"data": {"id": "Gian Marco Ferrari", "related": "Gian Marco Ferrari"}}, {"data": {"id": "Davide Astori", "related": "Davide Astori|Federico Bernardeschi"}}, {"data": {"id": "Federico Bernardeschi", "related": "Davide Astori|Federico Bernardeschi"}}, {"data": {"id": "Danilo D\'Ambrosio", "related": "Danilo D\'Ambrosio|Antonio Candreva|Roberto Gagliardini|\\u00c9der"}}, {"data": {"id": "Antonio Candreva", "related": "Danilo D\'Ambrosio|Antonio Candreva|Roberto Gagliardini|\\u00c9der"}}, {"data": {"id": "Roberto Gagliardini", "related": "Danilo D\'Ambrosio|Antonio Candreva|Roberto Gagliardini|\\u00c9der"}}, {"data": {"id": "\\u00c9der", "related": "Danilo D\'Ambrosio|Antonio Candreva|Roberto Gagliardini|\\u00c9der"}}, {"data": {"id": "Gianluigi Buffon (captain)", "related": "Gianluigi Buffon (captain)|Giorgi
# ...

# %% [markdown]
# ### Hierarchical with Clubs

# %%
N=len(players)
club_lookup=players['Club'].unique()
M=len(club_lookup)
adj_matrix=np.zeros((N+M,N+M))
for club,club_players in players.groupby("Club"):
    club_idx=np.where(club_lookup==club)[0][0]+N
    for idx in club_players.index:
        adj_matrix[idx][club_idx]=1
        adj_matrix[club_idx][idx]=1
G=nx.from_numpy_matrix(adj_matrix)
nx.draw(G,pos=nx.spring_layout(G))

# %%
#to Cytoscape
nodes=[]
edges=[]

for club,club_players in players.groupby("Club"):
    for idx, p in club_players.iterrows():
        nodes.append({"data": {"id": p["Player"],"related":club}})
    nodes.append({"data":{"id": club}})
    club_idx=np.where(club_lookup==club)[0][0]+N
    for idx in club_players.index:
        edges.append({"data": {"target": players.ix[idx]['Player'], "source": club}})
elements={"nodes": nodes, "edges":edges}

# %%
for p in players["Player"]:
        print(""".selector("[id='%s']")
      .css({
        'background-image': 'https://yt3.ggpht.com/-U1lXzI1lYs0/AAAAAAAAAAI/AAAAAAAAAAA/i6pBduc7uUc/s900-c-k-no-mo-rj-c0xffffff/photo.jpg'
      })"""%p)
# Out:
# .selector("[id='Gianluigi Buffon (captain)']")
#       .css({
#         'background-image': 'https://yt3.ggpht.com/-U1lXzI1lYs0/AAAAAAAAAAI/AAAAAAAAAAA/i6pBduc7uUc/s900-c-k-no-mo-rj-c0xffffff/photo.jpg'
#       })
# .selector("[id='Gianluigi Donnarumma']")
#       .css({
#         'background-image': 'https://yt3.ggpht.com/-U1lXzI1lYs0/AAAAAAAAAAI/AAAAAAAAAAA/i6pBduc7uUc/s900-c-k-no-mo-rj-c0xffffff/photo.jpg'
#       })
# .selector("[id='Simone Scuffet']")
#       .css({
#         'background-image': 'https://yt3.ggpht.com/-U1lXzI1lYs0/AAAAAAAAAAI/AAAAAAAAAAA/i6pBduc7uUc/s900-c-k-no-mo-rj-c0xffffff/photo.jpg'
#       })
# .selector("[id='Andrea Conti']")
#       .css({
#         'background-image': 'https://yt3.ggpht.com/-U1lXzI1lYs0/AAAAAAAAAAI/AAAAAAAAAAA/i6pBduc7uUc/s900-c-k-no-mo-rj-c0xffffff/photo.jpg'
#       })
# .selector("[id='Giorgio Chiellini']")
#       .css({
# ...

# %%
for c in club_lookup:
    print(""".selector('#%s')
      .css({
        'background-image': ''
      })"""%c)
# Out:
# .selector('#Juventus')
#       .css({
#         'background-image': ''
#       })
# .selector('#Milan')
#       .css({
#         'background-image': ''
#       })
# .selector('#Udinese')
#       .css({
#         'background-image': ''
#       })
# .selector('#Atalanta')
#       .css({
#         'background-image': ''
#       })
# .selector('#Manchester United')
#       .css({
#         'background-image': ''
#       })
# .selector('#Fiorentina')
#       .css({
#         'background-image': ''
#       })
# .selector('#Internazionale')
#       .css({
#         'background-image': ''
#       })
# .selector('#Crotone')
#       .css({
#         'background-image': ''
#       })
# .selector('#Roma')
#       .css({
#         'background-image': ''
#       })
# .selector('#Torino')
#       .css({
#         'background-image': ''
#       })
# .selector('#Napoli')
#       .css({
#         'background-image': ''
#       })
# .selector('#Lazio')
#       .css({
#         'background-image': ''
# ...

# %%
dumps(elements)
# Out:
# '{"nodes": [{"data": {"id": "Andrea Conti", "related": "Atalanta"}}, {"data": {"id": "Leonardo Spinazzola", "related": "Atalanta"}}, {"data": {"id": "Atalanta"}}, {"data": {"id": "Gian Marco Ferrari", "related": "Crotone"}}, {"data": {"id": "Crotone"}}, {"data": {"id": "Davide Astori", "related": "Fiorentina"}}, {"data": {"id": "Federico Bernardeschi", "related": "Fiorentina"}}, {"data": {"id": "Fiorentina"}}, {"data": {"id": "Danilo D\'Ambrosio", "related": "Internazionale"}}, {"data": {"id": "Antonio Candreva", "related": "Internazionale"}}, {"data": {"id": "Roberto Gagliardini", "related": "Internazionale"}}, {"data": {"id": "\\u00c9der", "related": "Internazionale"}}, {"data": {"id": "Internazionale"}}, {"data": {"id": "Gianluigi Buffon (captain)", "related": "Juventus"}}, {"data": {"id": "Giorgio Chiellini", "related": "Juventus"}}, {"data": {"id": "Andrea Barzagli", "related": "Juventus"}}, {"data": {"id": "Leonardo Bonucci", "related": "Juventus"}}, {"data": {"id": "Juventus"}
# ...

# %%
G=nx.cubical_graph()
pos=nx.spring_layout(G) # positions for all nodes

# nodes
nx.draw_networkx_nodes(G,pos,
                       nodelist=[0,1,2,3],
                       node_color='r',
                       node_size=500,
                   alpha=0.8)
nx.draw_networkx_nodes(G,pos,
                       nodelist=[4,5,6,7],
                       node_color='b',
                       node_size=500,
                   alpha=0.8)

# edges
nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
nx.draw_networkx_edges(G,pos,
                       edgelist=[(0,1),(1,2),(2,3),(3,0)],
                       width=8,alpha=0.5,edge_color='r')
nx.draw_networkx_edges(G,pos,
                       edgelist=[(4,5),(5,6),(6,7),(7,4)],
                       width=8,alpha=0.5,edge_color='b')


# some math labels
labels={}
labels[0]=r'$a$'
labels[1]=r'$b$'
labels[2]=r'$c$'
labels[3]=r'$d$'
labels[4]=r'$\alpha$'
labels[5]=r'$\beta$'
labels[6]=r'$\gamma$'
labels[7]=r'$\delta$'
nx.draw_networkx_labels(G,pos,labels,font_size=16)

plt.axis('off')
plt.savefig("labels_and_colors.png") # save as png
plt.show() # display
