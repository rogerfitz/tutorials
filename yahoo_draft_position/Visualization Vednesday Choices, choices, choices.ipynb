# %% [markdown]
# This could be good for a Linked In post. Gear towards professionals that deal with distributions of data. Make a slideshare

# %% [markdown]
# HOOKem with interesting visualization that needs more depth--aka click article. Gear this to/r/visualization too

# %% [markdown]
# What goes on behind visualizations.

# %%
import pandas as pd
pd.options.display.max_columns=None
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
league_standings=pd.read_csv("league_standings.csv")
league_standings.groupby("draft_position").agg([np.mean, np.median])['points_for'].plot()
plt.ylabel("Average Fantasy Points")
plt.xlabel("Draft Position")
plt.title("Draft Position vs Fantasy Points (Yahoo 10 Team)")

# %%
import seaborn as sns
sns.set( palette="pastel", color_codes=True)

# %% [markdown]
# Vertical encourages you to compare the boxes more than horizantal. But the distribution really doesn't contain memorable content, at the expense of a lot of distractions you learn that most groups are dispersed the same
# Mention optical illusion comparing rectangles
# http://blog.revolutionanalytics.com/2017/07/joyplots.html

# %%
sns.boxplot(y=league_standings['draft_position'],x=league_standings['points_for'],orient="h")

# %%
sns.boxplot(x=league_standings['draft_position'],y=league_standings['points_for'],orient="v")

# %%
sns.violinplot(y=league_standings['draft_position'],x=league_standings['points_for'],inner="quart", orient="h")
sns.despine(left=True)

# %%
sns.swarmplot(y=league_standings['draft_position'],x=league_standings['points_for'],orient="h")

# %% [markdown]
# For most fantasy football managers risk-reward preferences, getting first pick has the most enticing distribution. But 10th pick seems to have the most upside.

# %% [markdown]
# Create a joyplot IS THAT THE HOOK. ARRRRR. and talk about the latest fad in data viz.

# %%
league_standings[league_standings['number_of_moves']>0].plot(x="number_of_moves",y="points_for",kind="scatter")

# %%
league_standings
# Out:
#       clinched_playoffs  coverage_value  draft_position guid  has_draft_grade  \
# 0                   1.0              17               3   --                0
# 1                   1.0              17               8  NaN                0
# 2                   1.0              17               5  NaN                0
# 3                   1.0              17               7   --                0
# 4                   NaN              17               1  NaN                0
# 5                   NaN              17               2  NaN                0
# 6                   NaN              17               9  NaN                0
# 7                   NaN              17               6  NaN                0
# 8                   NaN              17               4  NaN                0
# 9                   NaN              17              10   --                0
# 10                  1.0              17               9  NaN                0
# ...
